# %%
# %run scripts/dowload_data.py
# Out:
# ============================================================
# HIGGS DATASET PREPARATION
# ============================================================
#
# [1/4] Downloading dataset
# ------------------------------------------------------------
# The compressed HIGGS dataset already exists. Skipping download.
#
# [2/4] Loading original dataset
# ------------------------------------------------------------
# Samples:  5,000,000
# Features: 18
# Columns:  19
#
# Class distribution:
#   Class 0: 54.24%
#   Class 1: 45.76%
#
# [3/4] Creating 100% experimental reference dataset
# ------------------------------------------------------------
# Original size:   5,000,000
# Target size:     1,000,000
# Sampling method: Stratified sampling
# Random seed:     42
#
# 100% reference dataset:
#   Samples: 1,000,000
#
# Class distribution:
#   Class 0: 54.24%
#   Class 1: 45.76%
#
# [4/4] Generating datasets
# ------------------------------------------------------------
#
#    10% |    100,000 samples | Class 0: 54.25% | Class 1: 45.75%
#   Saved to: C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-10.csv
#
#    20% |    200,000 samples | Class 0: 54.20% | Class 1: 45.80%
#   Saved to: C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-20.csv
#
#    40% |    400,000 samples | Class 0: 54.23% | Class 1: 45.77%
#   Saved to: C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv
#
#    80% |    800,000 samples | Class 0: 54.25% | Class 1: 45.75%
#   Saved to: C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-80.csv
#
#   100% |  1,000,000 samples | Class 0: 54.24% | Class 1: 45.76%
#   Saved to: C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-100.csv
#
# ============================================================
# DATASET PREPARATION COMPLETED
# ============================================================

# %%
# %run scripts/AL_performance.py 4 40 smart 10 performance_40_size_4_cores.csv
# Out:
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,075 instances
#   Test set size: 119,925 instances
#
# Initial training set state:
#   Labeled (L):   14,165 instances (5.06%)
#   Unlabeled (U): 265,910 instances (94.94%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 10
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6381
#
# ============================================================
# ACTIVE LEARNING LOOP
# ============================================================
#
# --- Active Learning iteration 1/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9537.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,965 instances (6.06%)
#   Unlabeled (U): 263,110 instances (93.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6408
#
# --- Active Learning iteration 2/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9503.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   19,765 instances (7.06%)
#   Unlabeled (U): 260,310 instances (92.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6427
#
# --- Active Learning iteration 3/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9471.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   22,565 instances (8.06%)
#   Unlabeled (U): 257,510 instances (91.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6451
#
# --- Active Learning iteration 4/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9434.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   25,365 instances (9.06%)
#   Unlabeled (U): 254,710 instances (90.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6463
#
# --- Active Learning iteration 5/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9395.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   28,165 instances (10.06%)
#   Unlabeled (U): 251,910 instances (89.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6471
#
# --- Active Learning iteration 6/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9360.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   30,965 instances (11.06%)
#   Unlabeled (U): 249,110 instances (88.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6482
#
# --- Active Learning iteration 7/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9313.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   33,765 instances (12.06%)
#   Unlabeled (U): 246,310 instances (87.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6482
#
# --- Active Learning iteration 8/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9265.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   36,565 instances (13.06%)
#   Unlabeled (U): 243,510 instances (86.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6488
#
# --- Active Learning iteration 9/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9220.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   39,365 instances (14.06%)
#   Unlabeled (U): 240,710 instances (85.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6497
#
# --- Active Learning iteration 10/10 ---
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9180.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   42,165 instances (15.05%)
#   Unlabeled (U): 237,910 instances (84.95%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6498

# %%
# %run scripts/AL_performance.py 4 40 random 10 performance_40_size_4_cores.csv
# Out:
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,075 instances
#   Test set size: 119,925 instances
#
# Initial training set state:
#   Labeled (L):   14,165 instances (5.06%)
#   Unlabeled (U): 265,910 instances (94.94%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 10
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Random selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6381
#
# ============================================================
# ACTIVE LEARNING LOOP
# ============================================================
#
# --- Active Learning iteration 1/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,965 instances (6.06%)
#   Unlabeled (U): 263,110 instances (93.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6377
#
# --- Active Learning iteration 2/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   19,765 instances (7.06%)
#   Unlabeled (U): 260,310 instances (92.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6389
#
# --- Active Learning iteration 3/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   22,565 instances (8.06%)
#   Unlabeled (U): 257,510 instances (91.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6396
#
# --- Active Learning iteration 4/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   25,365 instances (9.06%)
#   Unlabeled (U): 254,710 instances (90.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6395
#
# --- Active Learning iteration 5/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   28,165 instances (10.06%)
#   Unlabeled (U): 251,910 instances (89.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6403
#
# --- Active Learning iteration 6/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   30,965 instances (11.06%)
#   Unlabeled (U): 249,110 instances (88.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6409
#
# --- Active Learning iteration 7/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   33,765 instances (12.06%)
#   Unlabeled (U): 246,310 instances (87.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6409
#
# --- Active Learning iteration 8/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   36,565 instances (13.06%)
#   Unlabeled (U): 243,510 instances (86.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6414
#
# --- Active Learning iteration 9/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   39,365 instances (14.06%)
#   Unlabeled (U): 240,710 instances (85.94%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6416
#
# --- Active Learning iteration 10/10 ---
# Random selection method started.
# random_selection():
# 	- Marking 2800 random selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   42,165 instances (15.05%)
#   Unlabeled (U): 237,910 instances (84.95%)
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6415

# %%
from scripts.plot_results import plot_performance_results

plot_performance_results("performance_40_size_4_cores.csv", custom_range=[0.6,0.7])
# Out:
# method  labeled_percentage  Random Selection  Uncertainty + K-means
# 0                      5.0            0.6381                 0.6381
# 1                      6.0            0.6377                 0.6408
# 2                      7.0            0.6389                 0.6427
# 3                      8.0            0.6396                 0.6451
# 4                      9.0            0.6395                 0.6463
# 5                     10.0            0.6403                 0.6471
# 6                     11.0            0.6409                 0.6482
# 7                     12.0            0.6409                 0.6482
# 8                     13.0            0.6414                 0.6488
# 9                     14.0            0.6416                 0.6497
# 10                    15.0            0.6415                 0.6498

# %%
# ============================================================
# SPEED-UP
# ============================================================
#
# Para Speed-Up:
#
# - El tamaño del dataset se mantiene FIJO.
# - Cambiamos el número de cores.
#
# Aquí utilizamos el 10% del dataset.
#
# Experimentos:
#
#   (1 core, 100%)
#   (2 cores, 100%)
#   (4 cores, 100%)
#   (8 cores, 100%)
#   (12 cores, 100%)
#
# Cada experimento se repite 5 veces.
# ============================================================
print("===== SPEED-UP =====")
num_repetitions = 1
num_cores = [1, 2, 4, 8, 10]
percentage_set = 40
for cores in num_cores:

    for i in range(num_repetitions):
        print()
        print("-"*60)
        print(
            f"Cores={cores} | "
            f"Repetition {i + 1}/{num_repetitions} | "
            f"Dataset={percentage_set}%"
        )

        # %run scripts/AL_scalability.py $cores $percentage_set smart speed_up_bisectic.csv


print("Speed-Up experiment completed.\n")
# Out:
# ===== SPEED-UP =====
#
# ------------------------------------------------------------
# Cores=1 | Repetition 1/1 | Dataset=40%
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[1]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,067 instances
#   Test set size: 119,933 instances
#
# Initial training set state:
#   Labeled (L):   14,070 instances (5.02%)
#   Unlabeled (U): 265,997 instances (94.98%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6420
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9574.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,870 instances (6.02%)
#   Unlabeled (U): 263,197 instances (93.98%)
#
# ------------------------------------------------------------
# Cores=2 | Repetition 1/1 | Dataset=40%
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[2]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,090 instances
#   Test set size: 119,910 instances
#
# Initial training set state:
#   Labeled (L):   13,984 instances (4.99%)
#   Unlabeled (U): 266,106 instances (95.01%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6396
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9556.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,784 instances (5.99%)
#   Unlabeled (U): 263,306 instances (94.01%)
#
# ------------------------------------------------------------
# Cores=4 | Repetition 1/1 | Dataset=40%
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,075 instances
#   Test set size: 119,925 instances
#
# Initial training set state:
#   Labeled (L):   14,165 instances (5.06%)
#   Unlabeled (U): 265,910 instances (94.94%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6381
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9537.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,965 instances (6.06%)
#   Unlabeled (U): 263,110 instances (93.94%)
#
# ------------------------------------------------------------
# Cores=8 | Repetition 1/1 | Dataset=40%
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[8]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,625 instances
#   Test set size: 119,375 instances
#
# Initial training set state:
#   Labeled (L):   14,091 instances (5.02%)
#   Unlabeled (U): 266,534 instances (94.98%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6398
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9577.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,891 instances (6.02%)
#   Unlabeled (U): 263,734 instances (93.98%)
#
# ------------------------------------------------------------
# Cores=10 | Repetition 1/1 | Dataset=40%
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[10]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,481 instances
#   Test set size: 119,519 instances
#
# Initial training set state:
#   Labeled (L):   13,961 instances (4.98%)
#   Unlabeled (U): 266,520 instances (95.02%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6436
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9585.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,761 instances (5.98%)
#   Unlabeled (U): 263,720 instances (94.02%)
# Speed-Up experiment completed.

# %%
# ============================================================
# SIZE-UP
# ============================================================
#
# Para Size-Up:
#
# - El número de cores se mantiene FIJO.
# - Aumentamos el tamaño del dataset.
#
# Utilizamos 4 cores para todos los experimentos.
#
# Experimentos:
#
#   (4 cores, 10%)
#   (4 cores, 20%)
#   (4 cores, 40%)
#   (4 cores, 80%)
#   (4 cores, 100%)
#
# Cada experimento se repite 10 veces.
# ============================================================
print("===== SIZE-UP =====")
num_repetitions = 1
cores = 4
percentage_set = [10, 20, 40, 80, 100]
for percentage in percentage_set:

    for i in range(num_repetitions):
        print()
        print("-"*60)
        print(
            f"Dataset={percentage}% | " 
            f"Repetition {i + 1}/{num_repetitions} | "
            f"Cores={cores}"
        )

        # %run scripts/AL_scalability.py $cores $percentage smart size_up_bisectic.csv


print("Size-Up experiment completed.\n")
# Out:
# ===== SIZE-UP =====
#
# ------------------------------------------------------------
# Dataset=10% | Repetition 1/1 | Cores=4
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-10.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 100,000 instances
#   Training set size: 70,228 instances
#   Test set size: 29,772 instances
#
# Initial training set state:
#   Labeled (L):   3,584 instances (5.10%)
#   Unlabeled (U): 66,644 instances (94.90%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 702 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6423
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9562.
#
# Phase 2/2: Selecting 702 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=702...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 702 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   4,286 instances (6.10%)
#   Unlabeled (U): 65,942 instances (93.90%)
#
# ------------------------------------------------------------
# Dataset=20% | Repetition 1/1 | Cores=4
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-20.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 200,000 instances
#   Training set size: 140,268 instances
#   Test set size: 59,732 instances
#
# Initial training set state:
#   Labeled (L):   7,122 instances (5.08%)
#   Unlabeled (U): 133,146 instances (94.92%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 1,402 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6371
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9589.
#
# Phase 2/2: Selecting 1,402 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=1402...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 1402 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   8,524 instances (6.08%)
#   Unlabeled (U): 131,744 instances (93.92%)
#
# ------------------------------------------------------------
# Dataset=40% | Repetition 1/1 | Cores=4
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,075 instances
#   Test set size: 119,925 instances
#
# Initial training set state:
#   Labeled (L):   14,165 instances (5.06%)
#   Unlabeled (U): 265,910 instances (94.94%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6381
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9537.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,965 instances (6.06%)
#   Unlabeled (U): 263,110 instances (93.94%)
#
# ------------------------------------------------------------
# Dataset=80% | Repetition 1/1 | Cores=4
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-80.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 800,000 instances
#   Training set size: 559,758 instances
#   Test set size: 240,242 instances
#
# Initial training set state:
#   Labeled (L):   27,899 instances (4.98%)
#   Unlabeled (U): 531,859 instances (95.02%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 5,597 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6420
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9583.
#
# Phase 2/2: Selecting 5,597 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=5597...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 5597 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   33,496 instances (5.98%)
#   Unlabeled (U): 526,262 instances (94.02%)
#
# ------------------------------------------------------------
# Dataset=100% | Repetition 1/1 | Cores=4
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-100.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 1,000,000 instances
#   Training set size: 699,790 instances
#   Test set size: 300,210 instances
#
# Initial training set state:
#   Labeled (L):   34,778 instances (4.97%)
#   Unlabeled (U): 665,012 instances (95.03%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 6,997 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6433
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9590.
#
# Phase 2/2: Selecting 6,997 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=6997...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 6997 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   41,775 instances (5.97%)
#   Unlabeled (U): 658,015 instances (94.03%)
# Size-Up experiment completed.

# %%
# ============================================================
# SCALE-UP
# ============================================================
#
# Para Scale-Up aumentamos proporcionalmente:
#
#       número de cores
#
# y:
#
#       tamaño del dataset.
#
# Utilizamos las parejas:
#
#       1 core  -> 10%
#       2 cores -> 20%
#       4 cores -> 40%
#       8 cores -> 80%
#       12 cores -> 100%
#
# IMPORTANTE:
# En el script original de las diapositivas se utilizaba:
#
#       [1, 2, 4, 8, 10]
#
# porque los tamaños eran:
#
#       [10, 20, 40, 80, 100]
#
# Si queremos que la última ejecución utilice 12 cores,
# ya no existe una relación estrictamente proporcional.
#
# Por tanto, aquí utilizaremos 10 cores para el último punto.
# ============================================================

scaleup_cores = [1, 2, 4, 8, 10]
scaleup_sizes = [10, 20, 40, 80, 100]
num_repetitions = 1


print("===== SCALE-UP =====")

for cores, percentage in zip(
    scaleup_cores,
    scaleup_sizes
):
    for i in range(num_repetitions):
        print()
        print("-"*60)
        print(
            f"Dataset={percentage}% | " 
            f"Cores={cores} | "
            f"Repetition {i + 1}/{num_repetitions}"
        )

        # %run scripts/AL_scalability.py $cores $percentage smart scale_up_bisectic.csv

print("Size-Up experiment completed.\n")
# Out:
# ===== SCALE-UP =====
#
# ------------------------------------------------------------
# Dataset=10% | Cores=1 | Repetition 1/1
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[1]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-10.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 100,000 instances
#   Training set size: 69,941 instances
#   Test set size: 30,059 instances
#
# Initial training set state:
#   Labeled (L):   3,571 instances (5.11%)
#   Unlabeled (U): 66,370 instances (94.89%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 699 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6356
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9572.
#
# Phase 2/2: Selecting 699 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=699...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 699 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   4,270 instances (6.11%)
#   Unlabeled (U): 65,671 instances (93.89%)
#
# ------------------------------------------------------------
# Dataset=20% | Cores=2 | Repetition 1/1
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[2]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-20.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 200,000 instances
#   Training set size: 140,141 instances
#   Test set size: 59,859 instances
#
# Initial training set state:
#   Labeled (L):   7,199 instances (5.14%)
#   Unlabeled (U): 132,942 instances (94.86%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 1,401 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6408
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9550.
#
# Phase 2/2: Selecting 1,401 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=1401...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 1401 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   8,600 instances (6.14%)
#   Unlabeled (U): 131,541 instances (93.86%)
#
# ------------------------------------------------------------
# Dataset=40% | Cores=4 | Repetition 1/1
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[4]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-40.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 400,000 instances
#   Training set size: 280,075 instances
#   Test set size: 119,925 instances
#
# Initial training set state:
#   Labeled (L):   14,165 instances (5.06%)
#   Unlabeled (U): 265,910 instances (94.94%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 2,800 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6381
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9537.
#
# Phase 2/2: Selecting 2,800 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=2800...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 2800 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   16,965 instances (6.06%)
#   Unlabeled (U): 263,110 instances (93.94%)
#
# ------------------------------------------------------------
# Dataset=80% | Cores=8 | Repetition 1/1
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[8]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-80.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 800,000 instances
#   Training set size: 560,247 instances
#   Test set size: 239,753 instances
#
# Initial training set state:
#   Labeled (L):   28,267 instances (5.05%)
#   Unlabeled (U): 531,980 instances (94.95%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 5,602 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6407
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9568.
#
# Phase 2/2: Selecting 5,602 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=5602...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 5602 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   33,869 instances (6.05%)
#   Unlabeled (U): 526,378 instances (93.95%)
#
# ------------------------------------------------------------
# Dataset=100% | Cores=10 | Repetition 1/1
#
# ============================================================
#  STARTING SPARK ACTIVE LEARNING
# ============================================================
# Spark session initialized successfully on 'local[10]'
#
# ============================================================
#  LOAD AND PREPROCESS DATASET
# ============================================================
# load_and_preprocess_data():
# 	- Dataset loaded successfully from 'C:\Users\david\Documents\MASTER_CIENCIA_DE_DATOS\BLOQUE_BIGDATA\BIGDATA_2\ANALYTICS\ENTREGA\proyecto\data\higgs-100.csv'
# 	- Data types converted:
# 		-ID and label to INT
# 		-features to FLOAT.
# 	- Feature columns assembled into 'features' vector column
# 	- Dataset split into training and test sets.
# 	- Features standardized using statistics computed from the training set.
# 	- Training set initialized with approximately 5.0% labeled instances.
#
# ============================================================
# EXPERIMENT SETUP
# ============================================================
# Dataset configuration:
#   Train/Test split: [0.7, 0.3]
#   Total dataset size: 1,000,000 instances
#   Training set size: 700,272 instances
#   Test set size: 299,728 instances
#
# Initial training set state:
#   Labeled (L):   35,197 instances (5.03%)
#   Unlabeled (U): 665,075 instances (94.97%)
#   Initial labeled fraction: 5.0% of training set size.
#
# Active Learning configuration:
#   Number of iterations: 1
#   Query budget per iteration: 7,002 instances
#   Query batch fraction: 1.0% of training set size.
#
# Instance selection strategy:
#   Uncertainty filtering + K-Means diversity selection
#
# ============================================================
# INITIAL MODEL TRAINING AND EVALUATION
# ============================================================
# train_and_evaluate():
# 	- Training model on labeled instances...
# 	- Model evaluation completed -> accuracy = 0.6416
#
# ============================================================
# ACTIVE LEARNING ITERATION
# ============================================================
# Uncertainty filtering + K-Means diversity selection method started.
#
# Phase 1/2: Filtering candidates by uncertainty...
# get_uncertainty_candidates():
# 	- Computing uncertainty scores for unlabeled instances...
# 	- Computing threshold using approxQuantile...
# 	- Filtering unlabeled instances with uncertainty >= 0.9569.
#
# Phase 2/2: Selecting 7,002 diverse instances using K-Means...
# diversity_k_means_selection():
# 	- Running K-Means diversity selection with k=7002...
# 	- Selecting the candidate closest to each cluster centroid....
# 	- Marking 7002 selected instances as labeled in train_df...
#
# Training set state after labeling:
#   Labeled (L):   42,199 instances (6.03%)
#   Unlabeled (U): 658,073 instances (93.97%)
# Size-Up experiment completed.

# %%
from scripts.plot_results import plot_scalability

plot_scalability("speed_up.csv", "size_up.csv", "scale_up.csv")
